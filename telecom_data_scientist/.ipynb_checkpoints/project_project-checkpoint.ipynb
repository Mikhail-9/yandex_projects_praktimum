# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Телеком" data-toc-modified-id="Телеком-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Телеком</a></span><ul class="toc-item"><li><span><a href="#План-работы" data-toc-modified-id="План-работы-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>План работы</a></span></li><li><span><a href="#Предобработка" data-toc-modified-id="Предобработка-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Предобработка</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Построение-модели" data-toc-modified-id="Построение-модели-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Построение модели</a></span><ul class="toc-item"><li><span><a href="#CatBoost" data-toc-modified-id="CatBoost-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>CatBoost</a></span></li></ul></li><li><span><a href="#Отчёт" data-toc-modified-id="Отчёт-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Отчёт</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Телеком

# %% [markdown]
# ## План работы
# * Предобработка данных: ознакомиться с данными, объединить датасеты, обработать пропуски, дубликаты и некорректные значения, привести данные к корректным типам, выделить целевой признак, удалить лишние столбцы.
# * Исследовательский анализ данных: исследовать категориальные и количественные признаки, баланс классов целевого признака.
# * Построение модели: подготовить признаки к обучению, разделить датасет на выборки, обучить модель с различными гиперпараметрами и выбрать финальную модель с параметрами AUC-ROC ≥ 0.88.
# * Тестирование модели: проверить качество финальной модели на тестовой выборке.
# * Вывод: проанализировать полученные результаты.

# %%
# !pip install sweetviz -q

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as warn
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, accuracy_score, recall_score, precision_score, roc_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle
from imblearn.over_sampling import BorderlineSMOTE
import sweetviz as sv
from catboost import cv, Pool

# %% [markdown]
# ##  Предобработка

# %% [markdown]
# **Загрузим данные**

# %%
path_local = '/Users/bogda/anaconda3/projects/praktikum/project_project/final_provider/'
path_yandex = '/datasets/final_provider/'

# %%
files = ['contract', 'personal', 'internet', 'phone']
data = {}

# %%
def tryexept(path):
    for i in files:
        data[i] = pd.read_csv(path + i + '.csv', index_col= 'customerID')
        print('\n' + i)
        display(data[i].sample(5))
        data[i].info()
        print('—' * 54)

# %%
try:
    tryexept(path_local)
except FileNotFoundError as e:
    print(e)
    tryexept(path_yandex)
# Out:
# contract
#              BeginDate              EndDate            Type PaperlessBilling  \
# customerID
# 5844-QVTAT  2017-05-01                   No        One year              Yes
# 6368-TZZDT  2019-10-01                   No        Two year               No
# 0661-XEYAN  2019-09-01  2019-10-01 00:00:00  Month-to-month              Yes
# 3694-DELSO  2019-10-01                   No  Month-to-month               No
# 8563-OYMQY  2018-09-01                   No  Month-to-month              Yes
#
#                       PaymentMethod  MonthlyCharges TotalCharges
# customerID
# 5844-QVTAT             Mailed check           58.45       1955.4
# 6368-TZZDT  Credit card (automatic)           19.50        96.85
# 0661-XEYAN             Mailed check           25.80         25.8
# 3694-DELSO  Credit card (automatic)           38.55        156.1
# 8563-OYMQY  Credit card (automatic)           90.95       1612.2
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# **Небольшой обзор, пропусков нет(на первый взгляд:), две последних таблицы содержат меньше данных чем первые, причина в том что клиенты могут пользоваться разными услугами независимо - заполнить пропуски. Не соответсвтие типов данных и столбцов в таблице contract 'BeginDate', 'EndDate' - привести к дате, 'TotalCharges' к float.В таблице personal столбец 'SeniorSitizen' числовой хотя это категоральный признак. Разный регистр, нет целевого признака.**

# %% [markdown]
# **Объеденим таблицы в один датасет, приведем названия столбцов к одному регистру**

# %%
df = data['contract'].join(data['personal']).join(data['internet']).join(data['phone'])
df.columns = [k.lower() for k in list(df.columns)]
display(df.sample(5))
df.info()
# Out:
#              begindate              enddate            type paperlessbilling  \
# customerID
# 6507-DTJZV  2019-01-01                   No  Month-to-month               No
# 6575-SUVOI  2018-01-01                   No  Month-to-month              Yes
# 7321-ZNSLA  2019-01-01                   No        Two year               No
# 7643-RCHXS  2014-11-01                   No        Two year               No
# 3580-REOAC  2019-03-01  2020-01-01 00:00:00  Month-to-month              Yes
#
#                       paymentmethod  monthlycharges totalcharges  gender  \
# customerID
# 6507-DTJZV  Credit card (automatic)           66.40       831.75    Male
# 6575-SUVOI  Credit card (automatic)           69.50      1752.65  Female
# 7321-ZNSLA             Mailed check           40.55       590.35    Male
# 7643-RCHXS         Electronic check           19.35      1263.85  Female
# 3580-REOAC  Credit card (automatic)           44.85        435.4    Male
#
# ...

# %% [markdown]
# **Создадим столбец 'outflow' с целевым признаком**

# %%
def func(row):
    if row.enddate == "No":
        return 0
    else:
        return 1
df['outflow'] = df.apply(func, axis=1)

# %%
df
# Out:
#              begindate              enddate            type paperlessbilling  \
# customerID
# 7590-VHVEG  2020-01-01                   No  Month-to-month              Yes
# 5575-GNVDE  2017-04-01                   No        One year               No
# 3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month              Yes
# 7795-CFOCW  2016-05-01                   No        One year               No
# 9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month              Yes
# ...                ...                  ...             ...              ...
# 6840-RESVB  2018-02-01                   No        One year              Yes
# 2234-XADUH  2014-02-01                   No        One year              Yes
# 4801-JZAZL  2019-03-01                   No  Month-to-month              Yes
# 8361-LTMKD  2019-07-01  2019-11-01 00:00:00  Month-to-month              Yes
# 3186-AJIEK  2014-08-01                   No        Two year              Yes
#
# ...

# %% [markdown]
# **Заменим столбцы 'begindate', 'enddate' на столбец 'contract_length' так мы избавимся от утечки целевого признака и сохраним информативность временного признака. Для начала приведём их к дате и заменим пропуски на дату предоставления данных**

# %%
df['begindate'] = pd.to_datetime(df['begindate'], errors='coerce')
df['enddate'] = pd.to_datetime(df['enddate'], errors='coerce')

# %%
df['enddate'].fillna(pd.to_datetime('2020-02-01'), inplace=True)

# %%
def duration(row):
    return len(pd.date_range(start=row['begindate'], end=row['enddate']))
df['contract_length'] = df.apply(duration, axis=1)
df.drop(['begindate', 'enddate'], axis=1, inplace=True)

# %%
df
# Out:
#                       type paperlessbilling              paymentmethod  \
# customerID
# 7590-VHVEG  Month-to-month              Yes           Electronic check
# 5575-GNVDE        One year               No               Mailed check
# 3668-QPYBK  Month-to-month              Yes               Mailed check
# 7795-CFOCW        One year               No  Bank transfer (automatic)
# 9237-HQITU  Month-to-month              Yes           Electronic check
# ...                    ...              ...                        ...
# 6840-RESVB        One year              Yes               Mailed check
# 2234-XADUH        One year              Yes    Credit card (automatic)
# 4801-JZAZL  Month-to-month              Yes           Electronic check
# 8361-LTMKD  Month-to-month              Yes               Mailed check
# 3186-AJIEK        Two year              Yes  Bank transfer (automatic)
#
#             monthlycharges totalcharges  gender  seniorcitizen partner  \
# customerID
# ...

# %% [markdown]
# **Приведём данные столбца totalcharges к вещественному типу.**

# %%
df['totalcharges'] = pd.to_numeric(df['totalcharges'], errors='coerce')

# %% [markdown]
# **Изучим пропуски**

# %%
df[df['totalcharges'].isna()]
# Out:
#                 type paperlessbilling              paymentmethod  \
# customerID
# 4472-LVYGI  Two year              Yes  Bank transfer (automatic)
# 3115-CZMZD  Two year               No               Mailed check
# 5709-LVOEQ  Two year               No               Mailed check
# 4367-NUYAO  Two year               No               Mailed check
# 1371-DWPAZ  Two year               No    Credit card (automatic)
# 7644-OMVMY  Two year               No               Mailed check
# 3213-VVOLG  Two year               No               Mailed check
# 2520-SGTTA  Two year               No               Mailed check
# 2923-ARZLG  One year              Yes               Mailed check
# 4075-WKNIU  Two year               No               Mailed check
# 2775-SEFEE  Two year              Yes  Bank transfer (automatic)
#
#             monthlycharges  totalcharges  gender  seniorcitizen partner  \
# customerID
# 4472-LVYGI           52.55           NaN  Female              0     Yes
# ...

# %% [markdown]
# **Пропуски связаны с дилиноой контракта в один день, значит можем заменить их на 0**

# %%
df['totalcharges'].fillna(0, inplace=True)

# %% [markdown]
# **Приведём столбец 'seniorsitezen' к категоральному виду, каким он и является, заменив '1', '0' на ''YES, 'NO'.**

# %%
df['seniorcitizen'] = np.where(df['seniorcitizen'] == 1, 'YES', 'NO')

# %% [markdown]
# **Проверка**

# %%
df
# Out:
#                       type paperlessbilling              paymentmethod  \
# customerID
# 7590-VHVEG  Month-to-month              Yes           Electronic check
# 5575-GNVDE        One year               No               Mailed check
# 3668-QPYBK  Month-to-month              Yes               Mailed check
# 7795-CFOCW        One year               No  Bank transfer (automatic)
# 9237-HQITU  Month-to-month              Yes           Electronic check
# ...                    ...              ...                        ...
# 6840-RESVB        One year              Yes               Mailed check
# 2234-XADUH        One year              Yes    Credit card (automatic)
# 4801-JZAZL  Month-to-month              Yes           Electronic check
# 8361-LTMKD  Month-to-month              Yes               Mailed check
# 3186-AJIEK        Two year              Yes  Bank transfer (automatic)
#
#             monthlycharges  totalcharges  gender seniorcitizen partner  \
# customerID
# ...

# %% [markdown]
# **Изучим уникальные значения категоральных прризнаков**

# %%
cat_features = np.array(df.select_dtypes(include=['object']).columns)
for z in cat_features:
    print(z + ':', df[z].unique())
# Out:
# type: ['Month-to-month' 'One year' 'Two year']
# paperlessbilling: ['Yes' 'No']
# paymentmethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# gender: ['Female' 'Male']
# seniorcitizen: ['NO' 'YES']
# partner: ['Yes' 'No']
# dependents: ['No' 'Yes']
# internetservice: ['DSL' 'Fiber optic' nan]
# onlinesecurity: ['No' 'Yes' nan]
# onlinebackup: ['Yes' 'No' nan]
# deviceprotection: ['No' 'Yes' nan]
# techsupport: ['No' 'Yes' nan]
# streamingtv: ['No' 'Yes' nan]
# streamingmovies: ['No' 'Yes' nan]
# multiplelines: [nan 'No' 'Yes']

# %% [markdown]
# **Заполним пропуски 'None'**

# %%
df.fillna('None', inplace=True)
display(df.sample(7))
df.info()
# Out:
#                       type paperlessbilling              paymentmethod  \
# customerID
# 4781-ZXYGU  Month-to-month              Yes  Bank transfer (automatic)
# 2236-HILPA        Two year               No    Credit card (automatic)
# 9138-EFSMO        One year               No  Bank transfer (automatic)
# 0125-LZQXK  Month-to-month              Yes           Electronic check
# 9633-DENPU  Month-to-month              Yes  Bank transfer (automatic)
# 9153-BTBVV        Two year               No  Bank transfer (automatic)
# 0655-YDGFJ  Month-to-month               No  Bank transfer (automatic)
#
#             monthlycharges  totalcharges  gender seniorcitizen partner  \
# customerID
# 4781-ZXYGU           20.15         20.15    Male            NO     Yes
# 2236-HILPA           20.65       1218.45    Male            NO     Yes
# 9138-EFSMO           78.95       2034.25    Male            NO     Yes
# 0125-LZQXK          101.35       1553.95    Male            NO      No
# ...

# %% [markdown]
# **Проверим на дубли**

# %%
df.duplicated().sum()
# Out:
# 18

# %% [markdown]
# _Удалим дубли_

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# **Осмотрим датасет**

# %%
report = sv.analyze([df, 'review'])
# Out:
#                                              |                                             | [  0%]   00:00 ->…

# %%
report.show_html('review_analysis.html')
# Out:
# Report review_analysis.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# __Для открытия результатов используйте jupiter ==> file\open...\review_analysis.html__

# %% [markdown]
# **Вывод**
#
# **Имеем 7025 строк, 19 признаков - 16 категоральных(включая таргет), 3 числовых.**
#
# _Равная ритмичность графиков наводит на мысль что датасет сгенерирован:)_

# %% [markdown]
# **Сравним признаки с целевым**

# %%
report = sv.analyze([df,  'Outflow'], target_feat='outflow')
report.show_html('outflow.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report outflow.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# **Для открытия результатов используйте jupiter ==> file\open...\outflow.html**

# %% [markdown]
# **Выводы:**
#
# * Уровень изменения расчитан относительно одного признака
#
# * type – тип оплаты: ежемесячный, годовой двухлетний, отток клиентов максимален при помесячной оплате в четыре раза выше
#   чем при годовой и в десять чем при двухлетнем контракте
#
# * paperlessbilling – безбумажное выставление счетов, стимулирует к уходу в два раза чаще, по сравнению с бумажным
#
# * paymentmethod – способ оплаты, электронный чек в два раза повышает отток по сравнению с чеком по почте, бакновским             переводом(автоматическим), списанием с кредитной карты(автоматическим)
#
# * monthlycharges – ежемесячные траты на услуги, показывают очень слабую корреляцию при минимальном значении зависимости в точке   60
#
# * totalcharges – всего потрачено денег на услуги показывают очень слабую корреляцию при тенденции снижения при увеличении суммы
#   расходов
#
# * gender - пол, выявлен паритет
#
# * senior Citizen – наличие пенсионного статуса по возрасту, пенсионеры склонны в два раза чаще отказываться от услуг
#
# * partner – наличие супруга(и)  влияет слегка положительно и снижает отток на по этому признаку на треть, при очень слабой       корреляции
#
# * dependents – наличие иждивенцев, улучшает отток(снижает) в два раза
#
# * internetservise - наличие  оптики увеличивает отток в два раза по сравнению с DSL
#
# * onlinesecurity - наличие сервиса снижает отток почти  втри раза
#
# * onlinebackup - резеврное копирование онлайн снижает отток в два раза
#
# * deviceprotection - защита устройства удучшает отток на 42 %
#
# * techsupport - техническая поддержка почти в три раза уменьшает отток
#
# * streamingtv - стриминговое тв не влияет на отток
#
# * streamingmovies - стриминговый кинотеатр не влияет на отток
#
# * multipleLines – наличие возможности ведения параллельных линий во время звонка не влияет на отток
#
# * contract_length - длина контракта максимальное количество расторжений в первые дни и затем снижается

# %% [markdown]
# **Изучим численные признаки**

# %%
numerical = ['monthlycharges', 'totalcharges', 'contract_length']

# %%
df[numerical].corr()
# Out:
#                  monthlycharges  totalcharges  contract_length
# monthlycharges         1.000000      0.650703         0.245416
# totalcharges           0.650703      1.000000         0.825631
# contract_length        0.245416      0.825631         1.000000

# %% [markdown]
# __Признак totalcharges сильно коррелирует с признаками contract_length и monthlycharges, удалим его , чтобы избежать мультиколлинеарности.__

# %% [markdown]
# **Дополнительные сервисы оказывают влияние на отток,т.к. они в отдельности каждый уменьшают отток, то чем их больше тем меньше отток, создадим признак показывающий количество сервисов у клиента, заменив им все дополнительные сервисы удалив их. Также удалим gendre как неинформативный, и сбросим индексы**

# %%
additional_services = df.iloc[:, 10:16].columns

def services(row):
    n=0
    for i in additional_services:
        if row[i]=='Yes':
            n+=1
        if row[i]=='None':
            n=-1
    return n

df['services'] = df.apply(services, axis=1)

# %%
df.reset_index(drop=True, inplace=True)
df.drop(list(additional_services) + ['gender', 'totalcharges'], axis=1, inplace=True)

# %%
df
# Out:
#                 type paperlessbilling              paymentmethod  \
# 0     Month-to-month              Yes           Electronic check
# 1           One year               No               Mailed check
# 2     Month-to-month              Yes               Mailed check
# 3           One year               No  Bank transfer (automatic)
# 4     Month-to-month              Yes           Electronic check
# ...              ...              ...                        ...
# 7020        One year              Yes               Mailed check
# 7021        One year              Yes    Credit card (automatic)
# 7022  Month-to-month              Yes           Electronic check
# 7023  Month-to-month              Yes               Mailed check
# 7024        Two year              Yes  Bank transfer (automatic)
#
#       monthlycharges seniorcitizen partner dependents internetservice  \
# 0              29.85            NO     Yes         No             DSL
# ...

# %% [markdown]
# **Исследуем баланс классов целевого признака.**

# %%
round(df['outflow'].value_counts() / len(df), 2)
# Out:
# 0    0.74
# 1    0.26
# Name: outflow, dtype: float64

# %% [markdown]
# **Имеем дисбаланс объектов, нулевого класса почти в три раза больше , чем объектов единичного**

# %% [markdown]
# ### Вывод
#
# **Составим портрет самого надежного и лояльного клиента**
#
# _Это мужчина или женщина с двухлетним контрактом, предпочитающие бумажные счета, но оплачиваемые кредитной картой с автосписанием:), с месячной абонентской платой 60, в браке, с детьми, не пенсионного возраста,  использующие DSL, антивирус, резервное копирование, техническую поддержку и другие сервисы._

# %% [markdown]
# ## Построение модели

# %% [markdown]
# ### CatBoost

# %% [markdown]
# **Создадим списки признаков**

# %%
X = ['monthlycharges', 'contract_length', 'type', 'paperlessbilling', 'paymentmethod', 'seniorcitizen',
 'partner', 'dependents', 'internetservice', 'services',
'multiplelines']

cat_features = ['type', 'paperlessbilling', 'paymentmethod', 'seniorcitizen',
 'partner', 'dependents', 'internetservice', 'multiplelines'] 

y = ['outflow']

# %% [markdown]
# **Создадим обучающую и тестовую выборку**

# %%
train, test = train_test_split(df,train_size=0.8,random_state=77)

# %% [markdown]
# **Создание POOL**

# %%
train_data = Pool(data=train[X],
                  label=train[y],
                  cat_features=cat_features
                 )

# %%
test_data = Pool(data=test[X],
                  label=test[y],
                  cat_features=cat_features
                 )

# %% [markdown]
# **Кросс валидация**

# %%
params = {'cat_features': cat_features,
          'eval_metric': 'AUC',
          'loss_function': 'Logloss',
          'learning_rate': 0.11,
          'random_seed': 77,
          'verbose':100,
          'scale_pos_weight': 74/26}

# %%
cv_data = cv(
    params = params,
    pool = train_data,
    fold_count=5,
    shuffle=True,
    partition_random_seed=0,
    plot=True,
    stratified=True,
    verbose=False,
    early_stopping_rounds=200
)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))

# %% [markdown]
# **Найдём лучшую итерацию**

# %%
cv_data.head()
# Out:
#    iterations  test-AUC-mean  test-AUC-std  test-Logloss-mean  \
# 0           0       0.809179      0.009132           0.650075
# 1           1       0.826349      0.011508           0.619394
# 2           2       0.827459      0.011791           0.601689
# 3           3       0.830644      0.013401           0.581178
# 4           4       0.833419      0.012045           0.565596
#
#    test-Logloss-std  train-Logloss-mean  train-Logloss-std
# 0          0.003352            0.649431           0.004748
# 1          0.003365            0.617987           0.004241
# 2          0.005186            0.599791           0.008831
# 3          0.004798            0.578142           0.005117
# 4          0.004958            0.562210           0.003502

# %%
cv_data[cv_data['test-AUC-mean'] == cv_data['test-AUC-mean'].max()]
# Out:
#      iterations  test-AUC-mean  test-AUC-std  test-Logloss-mean  \
# 820         820       0.913715      0.015215            0.39365
#
#      test-Logloss-std  train-Logloss-mean  train-Logloss-std
# 820          0.045901            0.140905           0.005712

# %%
n_iters = cv_data[cv_data['test-AUC-mean'] == cv_data['test-AUC-mean'].max()]['iterations'].values[0]

# %%
n_iters
# Out:
# 820

# %% [markdown]
# **Обучение на всех данных**

# %%
params = {'cat_features': cat_features,
          'eval_metric': 'AUC',
          'loss_function': 'Logloss',
          'learning_rate': 0.11,
          'random_seed': 77,
          'verbose':100,
          'scale_pos_weight': 74/26,
          'iterations': 820}

# %%
model = CatBoostClassifier(**params)

# %%
model.fit(train_data)
# Out:
# 0:	total: 36.3ms	remaining: 29.8s
# 100:	total: 2.69s	remaining: 19.2s
# 200:	total: 5.4s	remaining: 16.6s
# 300:	total: 7.97s	remaining: 13.7s
# 400:	total: 10.6s	remaining: 11.1s
# 500:	total: 13.4s	remaining: 8.5s
# 600:	total: 15.9s	remaining: 5.81s
# 700:	total: 18.6s	remaining: 3.16s
# 800:	total: 21.2s	remaining: 504ms
# 819:	total: 21.8s	remaining: 0us

# %% [markdown]
# **Предсказание на тесте**

# %%
test['y_pred'] = model.predict_proba(test_data)[:,1]
# Out:
# C:\Users\bogda\AppData\Local\Temp/ipykernel_496/2601031922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['y_pred'] = model.predict_proba(test_data)[:,1]

# %%
roc_auc_score(test['outflow'],test['y_pred'])
# Out:
# 0.9314265015806112

# %% [markdown]
# **Необходимая точность достигнута, дальнейшее моделирование нецелесообразно**

# %% [markdown]
# ## Отчёт

# %% [markdown]
# В ходе выполнения проекта мы объеденили разрозненые таблицы в одну. Данные были предварительно обработаны и проанализированы с использованием библиотеки sweetviz. В процессе создал несколько новых признаков(целевой признак, длительность договора в днях, количество дополнительных интернет услуг) и удалил часть имеющихся. Выявлен дисбаланс класса в отношении 74 к 26.
# На полученных данных сгрупировали признаки по категориям и обучили модель градиентного бустинга Catboost получив на нём результат
#
# **AUC-ROC = 0.931**
#
# мы достигли целей поставленных в начале работы.

# %% [markdown]
# _Из параметров обученной модели в пятерке признаков лидеров по важности имеем:_
# * contract_length
# * monthtlycharges
# * type
# * internetservices
# * multilelines

# %%
importance = pd.Series(model.feature_importances_, index=X).sort_values()

fig, ax = plt.subplots()
fig.set_size_inches(7, 8)
plt.barh(importance.index, importance)
ax.set_title('Важность признаков', fontsize=11)
ax.grid(True)
ax.tick_params(labelsize=12)
